# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/siddharth/anaconda3/lib/python3.8/site-packages (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/siddharth/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/siddharth/anaconda3/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /home/siddharth/anaconda3/lib/python3.8/site-packages (from pandas) (1.20.1)
# Requirement already satisfied: six>=1.5 in /home/siddharth/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
import pandas as pd
df = pd.read_csv("Summer.csv", delimiter=',')
display(df)
#df.dropna(inplace=True)
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
len(df['City'].unique())
# Out:
# 22

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
d = []
data = df[df["Medal"] == "Gold"][["Sport","Medal"]]
data
for Sport in data['Sport'].unique():
    d.append([Sport , len(data[data['Sport']  == Sport])])
res = pd.DataFrame(d,columns = ['Sport','Medal']).sort_values(by='Medal', ascending=False).head()
print(res)
res.plot(x = 'Sport',y = 'Medal', kind = 'bar', figsize = (5,5))
# Out:
#          Sport  Medal
# 0     Aquatics   1421
# 1    Athletics   1215
# 17      Rowing    890
# 4   Gymnastics    820
# 3      Fencing    552
# <AxesSubplot:xlabel='Sport'>

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
res = df.groupby('Sport').count()['Medal'].sort_values(ascending = False).head()
print(res)
res.plot.bar()
# Out:
# Sport
# Aquatics      4170
# Athletics     3638
# Rowing        2667
# Gymnastics    2307
# Fencing       1613
# Name: Medal, dtype: int64
# <AxesSubplot:xlabel='Sport'>

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
data = []
for Athlete in df['Athlete'].unique():
    data.append([Athlete , len(df[df['Athlete']  == Athlete])])
res = pd.DataFrame(data,columns = ['Athlete','Medal']).sort_values(by='Medal', ascending=False).head()
print(res)
res.plot(x = 'Athlete',y = 'Medal', kind = 'bar', figsize = (5,5))
# Out:
#                     Athlete  Medal
# 18640       PHELPS, Michael     22
# 7197       LATYNINA, Larisa     18
# 9948     ANDRIANOV, Nikolay     15
# 6591           ONO, Takashi     13
# 5103   MANGIAROTTI, Edoardo     13
# <AxesSubplot:xlabel='Athlete'>

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
d = []
data = df[df["Medal"] == "Gold"][["Athlete","Medal"]]
data
for Athlete in data['Athlete'].unique():
    d.append([Athlete , len(data[data['Athlete']  == Athlete])])
res = pd.DataFrame(d,columns = ['Athlete','Medal']).sort_values(by='Medal', ascending=False).head()
print(res)
res.plot(x = 'Athlete',y = 'Medal', kind = 'bar', figsize = (5,5))
# Out:
#                Athlete  Medal
# 6851   PHELPS, Michael     18
# 3320       SPITZ, Mark      9
# 2714  LATYNINA, Larisa      9
# 4630       LEWIS, Carl      9
# 907       NURMI, Paavo      9
# <AxesSubplot:xlabel='Athlete'>

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
data = df[df["Country"] == "IND"][["Year","Medal"]]
data = data[data["Medal"] == "Gold"]
print(data.iloc[0]["Year"])
# Out:
# 1928

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
data=[]
for Event in df["Event"].unique():
  data.append([Event, len(df[df["Event"]==Event])])
event=pd.DataFrame(data,columns=["EVENT","PLAYERS"])
event=event.sort_values(by="PLAYERS",ascending=False).head()
print(event)
event.plot(x="EVENT",y="PLAYERS",kind="bar",figsize=(5,5))
# Out:
#                 EVENT  PLAYERS
# 80           Football     1497
# 176            Hockey     1422
# 138  Team Competition     1147
# 327        Basketball     1012
# 337          Handball      973
# <AxesSubplot:xlabel='EVENT'>

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
d = []
data = df[df["Gender"] == "Women"]
data = data[data["Medal"] == "Gold"][["Sport", "Gender"]]
for Sport in data['Sport'].unique():
    d.append([Sport , len(data[data['Sport']  == Sport])])
res = pd.DataFrame(d,columns = ['Sport','Medal']).sort_values(by='Medal', ascending=False).head()
print(res)
res.plot(x = 'Sport',y = 'Medal', kind = 'bar', figsize = (5,5))
# Out:
#          Sport  Medal
# 4     Aquatics    589
# 7    Athletics    389
# 8   Gymnastics    268
# 14      Rowing    217
# 11  Volleyball    166
# <AxesSubplot:xlabel='Sport'>
